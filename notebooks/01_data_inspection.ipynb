# %% [markdown]
# # Part 1: Data Inspection
# ## Green-Synthesized ZnO Nanoparticle Research Project
#
# This notebook inspects the raw experimental synthesis and characterization dataset (`zn_particle.xlsx`).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_excel('../data/raw/zn_particle.xlsx')
print("Dataset Shape:", df.shape)
df.head()

# %%
# Data Info & Summary Statistics
print("--- Dataset Information ---")
df.info()

print("\n--- Null Values Check ---")
print(df.isnull().sum())

print("\n--- Duplicate Rows Check ---")
print("Duplicates count:", df.duplicated().sum())

print("\n--- Summary Statistics ---")
df.describe().T
